# %%
import vertexai_start
# Out:
# /home/diogo/miniconda3/envs/vertexai_env/lib/python3.9/site-packages/requests/__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(
# Vertex AI initialized

# %%
from  vertexai.generative_models import GenerativeModel
from vertexai.generative_models import GenerationConfig
model = GenerativeModel("gemini-2.5-flash-lite")
res = model.generate_content("What is the capital of Portugal? in a few words") 
res.text
# Out:
# /home/diogo/miniconda3/envs/vertexai_env/lib/python3.9/site-packages/vertexai/generative_models/_generative_models.py:433: UserWarning: This feature is deprecated as of June 24, 2025 and will be removed on June 24, 2026. For details, see https://cloud.google.com/vertex-ai/generative-ai/docs/deprecations/genai-vertexai-sdk.
#   warning_logs.show_deprecation_warning()
# 'Lisbon.'

# %% [markdown]
# # Prompt Engineering

# %% [markdown]
# # 1. Be concise

# %% [markdown]
# p1 = "Could you kindly propose an imaginative solution to the problem of plastic waste in our oceans?"
#
# **Concise version**:
#
# p2 = "Propose an imaginative solution to plastic waste in oceans."

# %%
p1 = "Could you kindly propose an imaginative solution to the problem of plastic waste in our oceans?"
p2 = "Propose an imaginative solution to plastic waste in oceans."
resp1 = model.generate_content(p1)
resp2 = model.generate_content(p2)

print("Original Prompt Response:", resp1.text)
print("==============================")
print("Concise Prompt Response:", resp2.text)
# Out:
# Original Prompt Response: Here's an imaginative solution to the problem of plastic waste in our oceans, focusing on a multi-pronged, bio-integrated approach:
#
# **The "Ocean Weaver" Initiative: A Bio-Augmented Symbiotic Ecosystem**
#
# This initiative envisions a future where our oceans aren't just recipients of our waste, but active participants in its remediation, guided by intelligent, bio-inspired technology.
#
# **Core Concept:**
#
# The Ocean Weaver Initiative proposes a network of semi-autonomous, bio-integrated "Weavers" – large, buoyant, and intelligent structures that actively seek, collect, and process plastic waste, transforming it into valuable resources or inert, bio-compatible materials, while simultaneously supporting marine life.
#
# **Key Components:**
#
# 1.  **Bio-Augmented "Weavers":**
# ...

# %% [markdown]
# ## Be specific and well defined

# %%
p1 = "Suggest a product name for a new eco-friendly water bottle."
p2 = "Suggest a catchy name for an eco-friendly water bottle, made from recycled materials, that keeps drinks cold for 24 hours."

resp1 = model.generate_content(p1)
resp2 = model.generate_content(p2)

print("Original Prompt Response:", resp1.text)
print("==============================")
print("Concise Prompt Response:", resp2.text)
# Out:
# Original Prompt Response: Here are some product name suggestions for a new eco-friendly water bottle, categorized by the vibe they evoke:
#
# **Focusing on Nature & Earth:**
#
# *   **Terra Sip:** Combines "Terra" (earth) with a common word for drinking.
# *   **Veridian Hydration:** "Veridian" evokes green and lushness.
# *   **EcoStream:** Suggests a flowing, natural, and eco-conscious source.
# *   **Grove Bottle:** Evokes a natural, shaded place.
# *   **Riverstone Hydrate:** Implies natural materials and purity.
# *   **Meadow Sip:** Gentle, natural, and refreshing.
# *   **Summit Source:** Suggests purity and high-quality water from nature.
# *   **Bloom Bottle:** Implies growth, renewal, and natural beauty.
# *   **Gaia's Vessel:** A more mystical and profound connection to Earth.
# *   **Arbor Hydrate:** "Arbor" relates to trees and greenery.
#
# **Highlighting Sustainability & Eco-Consciousness:**
#
# *   **Re:Flow:** Plays on "reusable" and the flow of water.
# ...
